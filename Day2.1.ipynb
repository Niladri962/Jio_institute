# %% [markdown]
# **Python Day 2**

# %%
#String Datatype
str = "Hello World"
print(str)
print(type(str))
# Out:
# Hello World
# <class 'str'>

# %% [markdown]
# String Methods

# %%
a = "hello"
b="LOWKEY"
print(a)
print(b)
print()
print("Upper Case String : ", a.upper())
print("Lower Case String : ", b.lower())
# Out:
# hello
# LOWKEY
#
# Upper Case String :  HELLO
# Lower Case String :  lowkey

# %%
s= " hello World   "
print(s)
# Out:
#  hello World

# %%
#capitalize each word
str = "hello my name is niladri"
print("Str: ", str.title())
# Out:
# Str:  Hello My Name Is Niladri

# %%
#split/any method used = give the location it store
str = "hello my name is niladri"
print(str.split)
# Out:
# <built-in method split of str object at 0x0000021A5351BCD0>

# %%
#split() = Change it into list
str = "hello my name is niladri"
print(str.split())
# Out:
# ['hello', 'my', 'name', 'is', 'niladri']

# %%
str= "Hello My name is Niladri"
print("Length : ", len(str))
# Out:
# Length :  24

# %%
text = "I like Java"
print(text.replace("Java", "Python"))
# Out:
# I like Python
