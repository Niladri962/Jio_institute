# %% [markdown]
# **List**
# 1. ordered
# 2. Changeable (mutable)
# 3. Allow duplicate values

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list1=["Apple", 87 , "Guava"]
print(list)
print(type(list))
# Out:
# ['Apple', 87, 'Guava', 'Banana', ['Guava', 56, 74], ['Guava', 56, 74, ['Guava', 56, 74]]]
# <class 'list'>

# %%
list1.append("Banana")
print(list)
# Out:
# ['Apple', 87, 'Guava', 'Banana']

# %%
list2=["Guava", 56, 74]
print(list1)

list1.append(list2)
print(list1)
# Out:
# ['Guava', 56, 74]
# ['Guava', 56, 74, ['Guava', 56, 74]]

# %%
fruits = ["apple", "banana", "mango"]
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'mango']

# %%
fruits = ["apple", "banana", "mango"]
fruits.append("Orange")
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'Orange']

# %%
#pop() ----->> only for int
fruits = ["apple", "banana", "mango"]
fruits.pop("banana")
print(fruits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 fruits = ["apple", "banana", "mango"]
# ----> 2 fruits.pop("banana")
#       3 print(fruits)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
fruits = ["apple", "banana", "mango"]
fruits.reverse()
print(fruits)
# Out:
# ['mango', 'banana', 'apple']
