# %% [markdown]
# In programming, the break and continue statements are used to alter the flow of loops:
#
# break exits the loop entirely
# continue skips the current iteration and proceeds to the next one

# %% [markdown]
# ✅ Simple Memory Trick
#
# break = STOP loop 🛑
#
# continue = SKIP step ⏭️

# %%
#exercise1
for i in range(10):
    if i==7:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(1,10):
    if i % 3==0:
        print("divisible")
        continue
    print(i)
# Out:
# 1
# 2
# divisible
# 4
# 5
# divisible
# 7
# 8
# divisible
